# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cyneuro/Neural-Networks-Machine-Learning/blob/master/XOR_notebooks/XOR_Example2.ipynb)

# %%
# %matplotlib inline

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

rng = np.random.RandomState(0)
X = rng.randn(1000, 2)
Y = np.logical_xor(X[:,0] > 0, X[:,1] > 0).astype(int)

c1 = X[np.nonzero(Y)[0]]
c2 = X[np.nonzero(Y == 0)[0]]

colors = ['red', 'blue']

plt.plot(c1[:,0], c1[:,1], 'ro', label='class 1')
plt.plot(c2[:,0], c2[:,1], 'bo', label='class 2')

plt.title('XOR') 
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

batch_size=8

training_data = DataLoader(TensorDataset(torch.Tensor(X[:750,:]), torch.tensor(Y[:750], dtype=torch.long)), shuffle=True, batch_size=batch_size)
validation_data = DataLoader(TensorDataset(torch.Tensor(X[750:,:]), torch.tensor(Y[750:], dtype=torch.long)), batch_size=batch_size)

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.activation = nn.ReLU()
        self.first_hidden = nn.Linear(2, 10)
        self.second_hidden = nn.Linear(10, 5)
        self.output = nn.Linear(5, 2)

    def forward(self, x):
        x = self.activation(self.first_hidden(x))
        x = self.activation(self.second_hidden(x))
        x = self.output(x)
        return x

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cuda device
# NeuralNetwork(
#   (activation): ReLU()
#   (first_hidden): Linear(in_features=2, out_features=10, bias=True)
#   (second_hidden): Linear(in_features=10, out_features=5, bias=True)
#   (output): Linear(in_features=5, out_features=2, bias=True)
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(training_data, model, loss_fn, optimizer)
    test(validation_data, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.730960  [    0/  750]
# Test Error:
#  Accuracy: 52.8%, Avg loss: 0.701568
#
# Epoch 2
# -------------------------------
# loss: 0.697063  [    0/  750]
# Test Error:
#  Accuracy: 55.6%, Avg loss: 0.687321
#
# Epoch 3
# -------------------------------
# loss: 0.692286  [    0/  750]
# Test Error:
#  Accuracy: 49.2%, Avg loss: 0.679353
#
# Epoch 4
# -------------------------------
# loss: 0.713131  [    0/  750]
# Test Error:
#  Accuracy: 53.6%, Avg loss: 0.672772
#
# Epoch 5
# -------------------------------
# loss: 0.681670  [    0/  750]
# Test Error:
#  Accuracy: 57.2%, Avg loss: 0.666309
#
# Epoch 6
# -------------------------------
# loss: 0.674565  [    0/  750]
# Test Error:
#  Accuracy: 58.8%, Avg loss: 0.660021
#
# Epoch 7
# -------------------------------
# loss: 0.687229  [    0/  750]
# Test Error:
#  Accuracy: 60.0%, Avg loss: 0.653012
#
# Epoch 8
# -------------------------------
# loss: 0.717871  [    0/  750]
# Test Error:
#  Accuracy: 61.2%, Avg loss: 0.645724
#
# Epoch 9
# -------------------------------
# loss: 0.619226  [    0/  750]
# Test Error:
#  Accuracy: 62.4%, Avg loss: 0.637561
#
# Epoch 10
# -------------------------------
# loss: 0.684349  [    0/  750]
# Test Error:
#  Accuracy: 62.0%, Avg loss: 0.628403
#
# Epoch 11
# -------------------------------
# loss: 0.626204  [    0/  750]
# Test Error:
#  Accuracy: 62.4%, Avg loss: 0.618560
#
# Epoch 12
# -------------------------------
# loss: 0.519245  [    0/  750]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 0.606986
#
# Epoch 13
# -------------------------------
# loss: 0.505725  [    0/  750]
# Test Error:
#  Accuracy: 66.8%, Avg loss: 0.594693
#
# Epoch 14
# -------------------------------
# loss: 0.631491  [    0/  750]
# Test Error:
#  Accuracy: 68.0%, Avg loss: 0.581250
#
# Epoch 15
# -------------------------------
# loss: 0.668009  [    0/  750]
# Test Error:
#  Accuracy: 71.6%, Avg loss: 0.566027
#
# Epoch 16
# -------------------------------
# loss: 0.591841  [    0/  750]
# Test Error:
#  Accuracy: 74.8%, Avg loss: 0.547747
#
# Epoch 17
# -------------------------------
# loss: 0.559356  [    0/  750]
# Test Error:
#  Accuracy: 78.0%, Avg loss: 0.527661
#
# Epoch 18
# -------------------------------
# loss: 0.578559  [    0/  750]
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.503514
#
# Epoch 19
# -------------------------------
# loss: 0.595922  [    0/  750]
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.475845
#
# Epoch 20
# -------------------------------
# loss: 0.456627  [    0/  750]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.444520
#
# Epoch 21
# -------------------------------
# loss: 0.395996  [    0/  750]
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.412549
#
# Epoch 22
# -------------------------------
# loss: 0.331585  [    0/  750]
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.380172
#
# Epoch 23
# -------------------------------
# loss: 0.309258  [    0/  750]
# Test Error:
#  Accuracy: 94.8%, Avg loss: 0.347732
#
# Epoch 24
# -------------------------------
# loss: 0.365396  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.321537
#
# Epoch 25
# -------------------------------
# loss: 0.422303  [    0/  750]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.298913
#
# Epoch 26
# -------------------------------
# loss: 0.239375  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.279175
#
# Epoch 27
# -------------------------------
# loss: 0.255234  [    0/  750]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.264237
#
# Epoch 28
# -------------------------------
# loss: 0.124765  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.246943
#
# Epoch 29
# -------------------------------
# loss: 0.221004  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.236934
#
# Epoch 30
# -------------------------------
# loss: 0.181516  [    0/  750]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.226938
#
# Epoch 31
# -------------------------------
# loss: 0.168546  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.219205
#
# Epoch 32
# -------------------------------
# loss: 0.166066  [    0/  750]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.207716
#
# Epoch 33
# -------------------------------
# loss: 0.138210  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.203012
#
# Epoch 34
# -------------------------------
# loss: 0.115684  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.192736
#
# Epoch 35
# -------------------------------
# loss: 0.015702  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.182438
#
# Epoch 36
# -------------------------------
# loss: 0.263806  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.183165
#
# Epoch 37
# -------------------------------
# loss: 0.027428  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.174788
#
# Epoch 38
# -------------------------------
# loss: 0.097165  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.170783
#
# Epoch 39
# -------------------------------
# loss: 0.128693  [    0/  750]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.169184
#
# Epoch 40
# -------------------------------
# loss: 0.163081  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.162510
#
# Epoch 41
# -------------------------------
# loss: 0.100119  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.160147
#
# Epoch 42
# -------------------------------
# loss: 0.133649  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.151659
#
# Epoch 43
# -------------------------------
# loss: 0.027445  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.149216
#
# Epoch 44
# -------------------------------
# loss: 0.206196  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.149717
#
# Epoch 45
# -------------------------------
# loss: 0.098163  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.147471
#
# Epoch 46
# -------------------------------
# loss: 0.082870  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.141660
#
# Epoch 47
# -------------------------------
# loss: 0.124683  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.143680
#
# Epoch 48
# -------------------------------
# loss: 0.118585  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.133963
#
# Epoch 49
# -------------------------------
# loss: 0.044590  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.132873
#
# Epoch 50
# -------------------------------
# loss: 0.138013  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.130932
#
# Epoch 51
# -------------------------------
# loss: 0.093789  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.137456
#
# Epoch 52
# -------------------------------
# loss: 0.172541  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.130299
#
# Epoch 53
# -------------------------------
# loss: 0.121943  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.126610
#
# Epoch 54
# -------------------------------
# loss: 0.004880  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.126470
#
# Epoch 55
# -------------------------------
# loss: 0.050192  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.120677
#
# Epoch 56
# -------------------------------
# loss: 0.065159  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.121175
#
# Epoch 57
# -------------------------------
# loss: 0.154804  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.117251
#
# Epoch 58
# -------------------------------
# loss: 0.058405  [    0/  750]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.114843
#
# Epoch 59
# -------------------------------
# loss: 0.035521  [    0/  750]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.115373
#
# Epoch 60
# -------------------------------
# loss: 0.148738  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.114765
#
# Epoch 61
# -------------------------------
# loss: 0.101299  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.110130
#
# Epoch 62
# -------------------------------
# loss: 0.035769  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.113059
#
# Epoch 63
# -------------------------------
# loss: 0.071951  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.108001
#
# Epoch 64
# -------------------------------
# loss: 0.059691  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.111305
#
# Epoch 65
# -------------------------------
# loss: 0.003381  [    0/  750]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.106433
#
# Epoch 66
# -------------------------------
# loss: 0.017243  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.113520
#
# Epoch 67
# -------------------------------
# loss: 0.059429  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.111057
#
# Epoch 68
# -------------------------------
# loss: 0.128237  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.102402
#
# Epoch 69
# -------------------------------
# loss: 0.077518  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.103167
#
# Epoch 70
# -------------------------------
# loss: 0.031364  [    0/  750]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.099162
#
# Epoch 71
# -------------------------------
# loss: 0.108043  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.100825
#
# Epoch 72
# -------------------------------
# loss: 0.025604  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.106550
#
# Epoch 73
# -------------------------------
# loss: 0.068214  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.095165
#
# Epoch 74
# -------------------------------
# loss: 0.157393  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.102716
#
# Epoch 75
# -------------------------------
# loss: 0.028010  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.099172
#
# Epoch 76
# -------------------------------
# loss: 0.011290  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.102105
#
# Epoch 77
# -------------------------------
# loss: 0.125359  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.097064
#
# Epoch 78
# -------------------------------
# loss: 0.115293  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.097026
#
# Epoch 79
# -------------------------------
# loss: 0.048393  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.099565
#
# Epoch 80
# -------------------------------
# loss: 0.014505  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.091758
#
# Epoch 81
# -------------------------------
# loss: 0.028677  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.091581
#
# Epoch 82
# -------------------------------
# loss: 0.008869  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.093802
#
# Epoch 83
# -------------------------------
# loss: 0.005201  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.094051
#
# Epoch 84
# -------------------------------
# loss: 0.055312  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.092869
#
# Epoch 85
# -------------------------------
# loss: 0.071456  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.090898
#
# Epoch 86
# -------------------------------
# loss: 0.003774  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.085383
#
# Epoch 87
# -------------------------------
# loss: 0.069478  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.084266
#
# Epoch 88
# -------------------------------
# loss: 0.057107  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.084394
#
# Epoch 89
# -------------------------------
# loss: 0.025561  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.092103
#
# Epoch 90
# -------------------------------
# loss: 0.076504  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.086717
#
# Epoch 91
# -------------------------------
# loss: 0.131262  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.085806
#
# Epoch 92
# -------------------------------
# loss: 0.047597  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.088696
#
# Epoch 93
# -------------------------------
# loss: 0.109764  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.083385
#
# Epoch 94
# -------------------------------
# loss: 0.066135  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.087052
#
# Epoch 95
# -------------------------------
# loss: 0.055281  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.080543
#
# Epoch 96
# -------------------------------
# loss: 0.024084  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.083007
#
# Epoch 97
# -------------------------------
# loss: 0.002791  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.082249
#
# Epoch 98
# -------------------------------
# loss: 0.049493  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.084348
#
# Epoch 99
# -------------------------------
# loss: 0.003432  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.078849
#
# Epoch 100
# -------------------------------
# loss: 0.008428  [    0/  750]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.077256
#
# Done!

# %%
def predict(x):
    #Convert into numpy element to tensor
    x = torch.from_numpy(x).type(torch.FloatTensor).to(device)
    #Predict and return ans
    ans = torch.argmax(model(x), dim=1)
    return ans.to('cpu').detach().numpy()

# %%
# Helper function to plot a decision boundary.
def plot_decision_boundary(pred_func,X,y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx,yy=np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.title('XOR')
    plt.xlabel('x axis')
    plt.ylabel('y axis')
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
#     plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.binary)
    plt.plot(c1[:,0], c1[:,1], 'ko', label='class 1')
    plt.plot(c2[:,0], c2[:,1], 'wo', label='class 2')
    plt.legend()
    plt.show()

# %%
plot_decision_boundary(lambda x : predict(x) ,X, Y)
