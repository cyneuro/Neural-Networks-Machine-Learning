# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cyneuro/Neural-Networks-Machine-Learning/blob/master/XOR_notebooks/XOR_Example2.ipynb)

# %%
# %matplotlib inline

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

rng = np.random.RandomState(0)
X = rng.randn(1000, 2)
Y = np.logical_xor(X[:,0] > 0, X[:,1] > 0).astype(int)

c1 = X[np.nonzero(Y)[0]]
c2 = X[np.nonzero(Y == 0)[0]]

colors = ['red', 'blue']

plt.plot(c1[:,0], c1[:,1], 'ro', label='class 1')
plt.plot(c2[:,0], c2[:,1], 'bo', label='class 2')

plt.title('XOR') 
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

batch_size=8

training_data = DataLoader(TensorDataset(torch.Tensor(X[:750,:]), torch.tensor(Y[:750], dtype=torch.long)), shuffle=True, batch_size=batch_size)
validation_data = DataLoader(TensorDataset(torch.Tensor(X[750:,:]), torch.tensor(Y[750:], dtype=torch.long)), batch_size=batch_size)

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.activation = nn.ReLU()
        self.first_hidden = nn.Linear(2, 10)
        self.second_hidden = nn.Linear(10, 5)
        self.output = nn.Linear(5, 2)

    def forward(self, x):
        x = self.activation(self.first_hidden(x))
        x = self.activation(self.second_hidden(x))
        x = self.output(x)
        return x

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cuda device
# NeuralNetwork(
#   (activation): ReLU()
#   (first_hidden): Linear(in_features=2, out_features=10, bias=True)
#   (second_hidden): Linear(in_features=10, out_features=5, bias=True)
#   (output): Linear(in_features=5, out_features=2, bias=True)
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(training_data, model, loss_fn, optimizer)
    test(validation_data, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.663318  [    0/  750]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 0.705889
#
# Epoch 2
# -------------------------------
# loss: 0.758244  [    0/  750]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 0.697650
#
# Epoch 3
# -------------------------------
# loss: 0.774581  [    0/  750]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 0.693592
#
# Epoch 4
# -------------------------------
# loss: 0.637599  [    0/  750]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 0.691309
#
# Epoch 5
# -------------------------------
# loss: 0.619642  [    0/  750]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 0.689892
#
# Epoch 6
# -------------------------------
# loss: 0.641694  [    0/  750]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 0.687764
#
# Epoch 7
# -------------------------------
# loss: 0.718513  [    0/  750]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 0.685891
#
# Epoch 8
# -------------------------------
# loss: 0.718937  [    0/  750]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 0.683752
#
# Epoch 9
# -------------------------------
# loss: 0.695581  [    0/  750]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 0.681194
#
# Epoch 10
# -------------------------------
# loss: 0.620733  [    0/  750]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 0.677475
#
# Epoch 11
# -------------------------------
# loss: 0.686095  [    0/  750]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 0.673180
#
# Epoch 12
# -------------------------------
# loss: 0.692395  [    0/  750]
# Test Error:
#  Accuracy: 50.8%, Avg loss: 0.668273
#
# Epoch 13
# -------------------------------
# loss: 0.624831  [    0/  750]
# Test Error:
#  Accuracy: 53.6%, Avg loss: 0.661709
#
# Epoch 14
# -------------------------------
# loss: 0.662002  [    0/  750]
# Test Error:
#  Accuracy: 54.0%, Avg loss: 0.654522
#
# Epoch 15
# -------------------------------
# loss: 0.627291  [    0/  750]
# Test Error:
#  Accuracy: 54.8%, Avg loss: 0.645222
#
# Epoch 16
# -------------------------------
# loss: 0.641658  [    0/  750]
# Test Error:
#  Accuracy: 55.6%, Avg loss: 0.633744
#
# Epoch 17
# -------------------------------
# loss: 0.663891  [    0/  750]
# Test Error:
#  Accuracy: 66.4%, Avg loss: 0.619048
#
# Epoch 18
# -------------------------------
# loss: 0.563470  [    0/  750]
# Test Error:
#  Accuracy: 69.2%, Avg loss: 0.602407
#
# Epoch 19
# -------------------------------
# loss: 0.627707  [    0/  750]
# Test Error:
#  Accuracy: 75.6%, Avg loss: 0.582655
#
# Epoch 20
# -------------------------------
# loss: 0.700767  [    0/  750]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.560038
#
# Epoch 21
# -------------------------------
# loss: 0.517073  [    0/  750]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.534900
#
# Epoch 22
# -------------------------------
# loss: 0.585492  [    0/  750]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.508065
#
# Epoch 23
# -------------------------------
# loss: 0.391687  [    0/  750]
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.481248
#
# Epoch 24
# -------------------------------
# loss: 0.353476  [    0/  750]
# Test Error:
#  Accuracy: 85.6%, Avg loss: 0.451690
#
# Epoch 25
# -------------------------------
# loss: 0.370793  [    0/  750]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.423204
#
# Epoch 26
# -------------------------------
# loss: 0.476285  [    0/  750]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.395387
#
# Epoch 27
# -------------------------------
# loss: 0.381869  [    0/  750]
# Test Error:
#  Accuracy: 92.0%, Avg loss: 0.369430
#
# Epoch 28
# -------------------------------
# loss: 0.416891  [    0/  750]
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.346732
#
# Epoch 29
# -------------------------------
# loss: 0.293802  [    0/  750]
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.326502
#
# Epoch 30
# -------------------------------
# loss: 0.332003  [    0/  750]
# Test Error:
#  Accuracy: 92.8%, Avg loss: 0.307381
#
# Epoch 31
# -------------------------------
# loss: 0.279349  [    0/  750]
# Test Error:
#  Accuracy: 93.2%, Avg loss: 0.289520
#
# Epoch 32
# -------------------------------
# loss: 0.253784  [    0/  750]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.274242
#
# Epoch 33
# -------------------------------
# loss: 0.181394  [    0/  750]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.261186
#
# Epoch 34
# -------------------------------
# loss: 0.420583  [    0/  750]
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.248888
#
# Epoch 35
# -------------------------------
# loss: 0.190448  [    0/  750]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.235629
#
# Epoch 36
# -------------------------------
# loss: 0.132093  [    0/  750]
# Test Error:
#  Accuracy: 95.2%, Avg loss: 0.225357
#
# Epoch 37
# -------------------------------
# loss: 0.088792  [    0/  750]
# Test Error:
#  Accuracy: 94.4%, Avg loss: 0.216226
#
# Epoch 38
# -------------------------------
# loss: 0.103297  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.205728
#
# Epoch 39
# -------------------------------
# loss: 0.072078  [    0/  750]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.196659
#
# Epoch 40
# -------------------------------
# loss: 0.227914  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.189604
#
# Epoch 41
# -------------------------------
# loss: 0.073046  [    0/  750]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.180895
#
# Epoch 42
# -------------------------------
# loss: 0.200252  [    0/  750]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.174734
#
# Epoch 43
# -------------------------------
# loss: 0.132104  [    0/  750]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.168500
#
# Epoch 44
# -------------------------------
# loss: 0.101236  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.164212
#
# Epoch 45
# -------------------------------
# loss: 0.100422  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.161376
#
# Epoch 46
# -------------------------------
# loss: 0.176515  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.154725
#
# Epoch 47
# -------------------------------
# loss: 0.091205  [    0/  750]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.149509
#
# Epoch 48
# -------------------------------
# loss: 0.043364  [    0/  750]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.146821
#
# Epoch 49
# -------------------------------
# loss: 0.093939  [    0/  750]
# Test Error:
#  Accuracy: 95.6%, Avg loss: 0.146434
#
# Epoch 50
# -------------------------------
# loss: 0.046568  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.137724
#
# Epoch 51
# -------------------------------
# loss: 0.036535  [    0/  750]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.136475
#
# Epoch 52
# -------------------------------
# loss: 0.137068  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.133881
#
# Epoch 53
# -------------------------------
# loss: 0.074529  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.128507
#
# Epoch 54
# -------------------------------
# loss: 0.134548  [    0/  750]
# Test Error:
#  Accuracy: 96.0%, Avg loss: 0.129287
#
# Epoch 55
# -------------------------------
# loss: 0.095078  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.122992
#
# Epoch 56
# -------------------------------
# loss: 0.141016  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.119649
#
# Epoch 57
# -------------------------------
# loss: 0.023107  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.122683
#
# Epoch 58
# -------------------------------
# loss: 0.052877  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.116790
#
# Epoch 59
# -------------------------------
# loss: 0.196897  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.117761
#
# Epoch 60
# -------------------------------
# loss: 0.024308  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.113180
#
# Epoch 61
# -------------------------------
# loss: 0.030047  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.117619
#
# Epoch 62
# -------------------------------
# loss: 0.039454  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.110364
#
# Epoch 63
# -------------------------------
# loss: 0.057685  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.107797
#
# Epoch 64
# -------------------------------
# loss: 0.028624  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.105094
#
# Epoch 65
# -------------------------------
# loss: 0.039341  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.103315
#
# Epoch 66
# -------------------------------
# loss: 0.050035  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.107925
#
# Epoch 67
# -------------------------------
# loss: 0.033583  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.100406
#
# Epoch 68
# -------------------------------
# loss: 0.013279  [    0/  750]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.106195
#
# Epoch 69
# -------------------------------
# loss: 0.006544  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.100640
#
# Epoch 70
# -------------------------------
# loss: 0.040338  [    0/  750]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.102575
#
# Epoch 71
# -------------------------------
# loss: 0.027131  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.098085
#
# Epoch 72
# -------------------------------
# loss: 0.008082  [    0/  750]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.101946
#
# Epoch 73
# -------------------------------
# loss: 0.201984  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.091920
#
# Epoch 74
# -------------------------------
# loss: 0.073579  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.091513
#
# Epoch 75
# -------------------------------
# loss: 0.098292  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.093387
#
# Epoch 76
# -------------------------------
# loss: 0.107644  [    0/  750]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.091104
#
# Epoch 77
# -------------------------------
# loss: 0.048122  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.096707
#
# Epoch 78
# -------------------------------
# loss: 0.047946  [    0/  750]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.085156
#
# Epoch 79
# -------------------------------
# loss: 0.287346  [    0/  750]
# Test Error:
#  Accuracy: 97.2%, Avg loss: 0.088762
#
# Epoch 80
# -------------------------------
# loss: 0.039287  [    0/  750]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.087412
#
# Epoch 81
# -------------------------------
# loss: 0.002362  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.084597
#
# Epoch 82
# -------------------------------
# loss: 0.056119  [    0/  750]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.086461
#
# Epoch 83
# -------------------------------
# loss: 0.006674  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.082630
#
# Epoch 84
# -------------------------------
# loss: 0.009344  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.083641
#
# Epoch 85
# -------------------------------
# loss: 0.007412  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.084050
#
# Epoch 86
# -------------------------------
# loss: 0.103443  [    0/  750]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.078435
#
# Epoch 87
# -------------------------------
# loss: 0.124283  [    0/  750]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.078870
#
# Epoch 88
# -------------------------------
# loss: 0.021429  [    0/  750]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.077229
#
# Epoch 89
# -------------------------------
# loss: 0.178790  [    0/  750]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.077805
#
# Epoch 90
# -------------------------------
# loss: 0.027464  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.077137
#
# Epoch 91
# -------------------------------
# loss: 0.099226  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.076610
#
# Epoch 92
# -------------------------------
# loss: 0.029511  [    0/  750]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.082175
#
# Epoch 93
# -------------------------------
# loss: 0.022633  [    0/  750]
# Test Error:
#  Accuracy: 98.8%, Avg loss: 0.082314
#
# Epoch 94
# -------------------------------
# loss: 0.006671  [    0/  750]
# Test Error:
#  Accuracy: 99.6%, Avg loss: 0.073100
#
# Epoch 95
# -------------------------------
# loss: 0.051845  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.083483
#
# Epoch 96
# -------------------------------
# loss: 0.047611  [    0/  750]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.085497
#
# Epoch 97
# -------------------------------
# loss: 0.018048  [    0/  750]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.072968
#
# Epoch 98
# -------------------------------
# loss: 0.076485  [    0/  750]
# Test Error:
#  Accuracy: 98.0%, Avg loss: 0.079032
#
# Epoch 99
# -------------------------------
# loss: 0.030752  [    0/  750]
# Test Error:
#  Accuracy: 98.4%, Avg loss: 0.075247
#
# Epoch 100
# -------------------------------
# loss: 0.018333  [    0/  750]
# Test Error:
#  Accuracy: 99.2%, Avg loss: 0.069050
#
# Done!

# %%
def predict(x):
    #Convert into numpy element to tensor
    x = torch.from_numpy(x).type(torch.FloatTensor).to(device)
    #Predict and return ans
    ans = torch.argmax(model(x), dim=1)
    return ans.to('cpu').detach().numpy()

# %%
# Helper function to plot a decision boundary.
def plot_decision_boundary(pred_func,X,y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx,yy=np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.title('XOR')
    plt.xlabel('x axis')
    plt.ylabel('y axis')
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
#     plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.binary)
    plt.plot(c1[:,0], c1[:,1], 'ko', label='class 1')
    plt.plot(c2[:,0], c2[:,1], 'wo', label='class 2')
    plt.legend()
    plt.show()

# %%
plot_decision_boundary(lambda x : predict(x) ,X, Y)
